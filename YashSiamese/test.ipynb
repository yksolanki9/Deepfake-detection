# %%
cd ../MasterDataset
# Out:
# /scratch/ysolanki/SiameseFacebook/MasterDataset

# %%
import numpy as np
data = np.load('Master-dataset-elvin-faces-embeddings-160x160.npz')
print(data)

# %%
train = data['arr_0']

# %%
train[2130]
# Out:
# array([-0.4881101 , -0.9685756 , -0.2967642 , -0.9615298 ,  0.75674516,
#         0.09545898, -0.24688682,  1.2954482 ,  0.7276366 , -0.74283135,
#         0.30369285, -0.7535528 , -0.18919554,  0.02122449, -0.30863228,
#        -0.40661752, -0.3364052 , -0.6188075 ,  0.36926845, -0.50776005,
#         0.2936329 , -0.1804259 , -0.42593387,  0.1438058 ,  0.6681552 ,
#        -1.3911802 ,  0.7731916 , -0.15100235, -0.20923688, -0.50019073,
#        -1.1324769 ,  0.01795047, -0.17440711,  0.78641784, -0.7552808 ,
#         0.10443981,  0.8758088 , -1.3796046 , -0.32573986, -1.0541657 ,
#        -0.11339615, -0.45024347,  0.1972851 , -0.26602316, -0.5776568 ,
#        -0.6608298 , -0.9549179 , -0.26231998,  0.57115453, -0.1452129 ,
#        -1.7398194 ,  1.1325034 , -0.01725882,  0.23869674, -1.2010661 ,
#        -0.14473888, -0.41545388, -0.6959933 , -0.8665506 ,  0.16953474,
#        -1.3554574 ,  1.1552091 ,  0.81548434,  1.8091104 ,  0.15459278,
# ...
